# %% [markdown]
# # Practica 04 : Analisis de Datos Exploratorio de Python y Jupiter Notebook

# %% [markdown]
# **Programa de Estudio:** Ingenieria en Desarrollo y Gestion de Software\
# **Asignatura:** Extraccion conocimineto en base de datos\
# **Docente:** M.T.I. Marco A. Ramirez Hernadez\
# **Periodo:** Mayo-Agosto 2026

# %% [markdown]
# **Nombre del Estudiante:** Carlos Daniel Garcia Pluma\
# **Matricula:** 230187\
# **Grado y Gupo:** 9° "A" IDGS

# %% [markdown]
# El estudiante practicara como realizar un analisis exploratorio de datos utilizando el lenguaje de progamacion de Python y librerias comunes para la carga, manipulacion, analisis y visualizacion previa de un conjunto de datos (Dataset)
#
# - Pandas
# - Numby
# - Seanborn
# - os
# - Matplotlib

# %% [markdown]
# 1.- Imoportar las librerias necesarias pra realizar el EDA
#
# comenzamos por importar la libreria que nos permitira manipular los datos del dataset extraidos de una fuente de datos (Datasource)

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# 2.- Creamos un DataFrame leyendo el archivo delimitando por comas (CSV)

# %%
pokemons=pd.read_csv('./Pokemon.csv')

# %% [markdown]
# 3.-Imprimimos el resultado de la lectura este comando imprime en una tabla las columnas y filas del data frame siempre de manera estandar nos motrara los primero 5 y los 5 registros ultimos del dataframe

# %%
pokemons
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# 4.- Obtenemos una muestra aleatoria de registros del dataframe usando el metodo simple como parametro de entrada podemos definir un entorno que determina el tamaño de la muestra

# %%
pokemons.sample(6)
# Out:
#        #                 Name    Type 1   Type 2  Total  HP  Attack  Defense  \
# 582  523            Zebstrika  Electric      NaN    497  75     100       63
# 85    79             Slowpoke     Water  Psychic    315  90      65       65
# 497  448              Lucario  Fighting    Steel    525  70     110       70
# 724  656              Froakie     Water      NaN    314  41      56       40
# 396  362               Glalie       Ice      NaN    480  80      80       80
# 460  413  WormadamTrash Cloak       Bug    Steel    424  60      69       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 582       80       63    116           5      False
# 85        40       40     15           1      False
# 497      115       70     90           4      False
# 724       62       44     71           6      False
# 396       80       80     80           3      False
# 460       69       95     36           4      False

# %% [markdown]
# **Ejercicio 1:** Obten una muestra de 50 pokemones

# %%
pokemons.sample(50)
# Out:
#        #                Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 535  479      RotomFan Rotom  Electric    Flying    520   50      65      107
# 103   95                Onix      Rock    Ground    385   35      45      160
# 641  580            Ducklett     Water    Flying    305   62      44       50
# 355  324             Torkoal      Fire       NaN    470   70      85      140
# 493  445            Garchomp    Dragon    Ground    600  108     130       95
# 62    57            Primeape  Fighting       NaN    455   65     105       60
# 276  255             Torchic      Fire       NaN    310   45      60       40
# 36    31           Nidoqueen    Poison    Ground    505   90      92       87
# 752  682            Spritzee     Fairy       NaN    341   78      52       60
# 685  624            Pawniard      Dark     Steel    340   45      85       70
# 440  395            Empoleon     Water     Steel    530   84      86       88
# ...

# %% [markdown]
# 5.- Obtener una muetra de rangos definidos usando **.iloc**

# %%
pokemons_100_to_200 = pokemons.iloc[100:200]
pokemons_100_to_200
# Out:
#        #                   Name    Type 1  Type 2  Total   HP  Attack  \
# 100   93                Haunter     Ghost  Poison    405   45      50
# 101   94                 Gengar     Ghost  Poison    500   60      65
# 102   94      GengarMega Gengar     Ghost  Poison    600   60      65
# 103   95                   Onix      Rock  Ground    385   35      45
# 104   96                Drowzee   Psychic     NaN    328   60      48
# ..   ...                    ...       ...     ...    ...  ...     ...
# 195  181               Ampharos  Electric     NaN    510   90      75
# 196  181  AmpharosMega Ampharos  Electric  Dragon    610   90      95
# 197  182              Bellossom     Grass     NaN    490   75      80
# 198  183                 Marill     Water   Fairy    250   70      20
# 199  184              Azumarill     Water   Fairy    420  100      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 100       45      115       55     95           1      False
# ...

# %% [markdown]
# 6.- Como saber las columnas o atributos tienen el dataframe

# %%
pokemons.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Campo Descripcion\
# **#:** EL ID o number de indentificacion del pokemon\
# **Name:** El nombre del Pokémon.\
# **Type 1:** Se refiere a las propiedades elementales (tipos) asociadas tanto al Pokémon como a sus movimientos\
# **Type 2:** Los Pokémon pueden tener hasta dos tipos (Pokémon de tipo dual), los movimientos solo pueden tener uno.\
# **Total:** Representa la suma de todos los stats, lo que te da una idea de qué tan "pesado" o fuerte es el Pokémon.\
# **HP:** (Puntos de Salud) Es qué tanto aguante tiene un Pokémon antes de que lo dejen fuera de combate (se desmaye).\
# **Attack:** La fuerza de los ataques físicos del Pokémon.\
# **Defense:** Qué tanto aguanta el Pokémon contra los ataques fisicos del rival.\
# **Sp. Atk:** Ataque Especial; el poder de los movimientos especiales del Pokémon.\
# **Sp. Def** Defensa Especial; qué tan resistente es el Pokémon ante los ataques especiales.\
# **Speed:** Velocidad, el Pokémon que tenga más velocidad es el que ataca primero.\
# **Generation:** Se refiere a la generación de la serie de juegos a la que pertenece.\
# **Legendary:** Indica si el Pokémon es Legendario o no (son bichos muy raros y poderosos). Es un valor booleano (si/no).

# %% [markdown]
# 7.- Explorar la composición y ausencia de datos (METADATA) con **.info**\
# La libreta de pandas, incliye un método que nos permite evaluar el tipo de datos y su composición y ausencia

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# 8.- Limpieza de datos
# Dependiendo del objetivo del analisis algunas columnas o registros no seran necesarias en nuetro datafrane, en este caso omitiremos los datos vacios, por lo que eleminarem0s la columna "Type 2" y renombraremos la columna "Type 1" por "Type"

# %%
del pokemons['Type 2']
pokemons.rename(columns={'Type 1' : 'Type'}, inplace = True)

# %% [markdown]
# **Ejercicio 02:** consulta la METADATA de la acrtualizacion y comparar los cambios con la anterior
# ¿Que cambios vez? redacta tu respuesta

# %% [markdown]
# 9.-Visualizacion de los primeros datos usando el metodo **head**

# %%
pokemons.head()
# Out:
#    #                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass    318  45      49       49       65
# 1  2                Ivysaur  Grass    405  60      62       63       80
# 2  3               Venusaur  Grass    525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 4  4             Charmander   Fire    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# **Ejercio 03** Muestra los ultimos 10 registros de dataframe

# %% [markdown]
# 10.-Estadistica basica del dataframe Pandas permite un reporte de estadisticas basica de tendencia sobre datos cuantitativos usando el comando **describe**

# %%
pokemons.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  805.000000  805.000000  805.000000  805.000000  805.000000  805.000000
# mean   361.638509  434.840994   69.151553   78.988820   73.831056   72.790062
# std    208.281603  119.775919   25.515177   32.480015   31.164246   32.658407
# min      1.000000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    184.000000  330.000000   50.000000   55.000000   50.000000   50.000000
# 50%    362.000000  450.000000   65.000000   75.000000   70.000000   65.000000
# 75%    538.000000  515.000000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.000000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  805.000000  805.000000  805.000000
# mean    71.828571   68.250932    3.313043
# std     27.793847   29.028107    1.662101
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %% [markdown]
# 11.- Para calcular el total de datos no duplicados (unicos)
# Usaremos **len()** como funciona para calcular la longitud del frame y **.unique()**\
# **NOTA** no considera 10 como u atributo de llave primaria, si nop el total de columknas como un solo elemento u objeto
#
# Obteniendo los valores unicos por columna en este caso columna "Name"

# %%
len(pokemons.Name.unique())
# Out:
# 800

# %%
Obteniendo el total de objetos (conjunto de atributos estrictamentes iguales) unicos

# %%
total_unicos=len(pokemons.drop_duplicates())
total_unicos
# Out:
# 800

# %% [markdown]
# **Ejercicio 04:** Obtener el total de IDs unicos en el dataset

# %%
len(pokemons['#'].unique())
# Out:
# 721

# %% [markdown]
# **Ejercicio 05:**  Obtener el total de tipos unicos de Pokemones

# %%
len(pokemons['Type 1'].unique())
# Out:
# 18

# %% [markdown]
# 12.- Contabilizacion de los datos por Atributos Pandas nos permite agrupar los datos y contabilizar los totales usando \
# **.value_counts()** ¿cuantos pokemones hay por generacion?

# %%
pokemons['Generation'].value_counts()
# Out:
# Generation
# 1    168
# 5    165
# 3    160
# 4    121
# 2    109
# 6     82
# Name: count, dtype: int64

# %% [markdown]
# 13.-Grafica Pokémon agrupados por generación: En este apartado de paginas nos permiten visualizar el comportamineto de los datos asi como sus nieveles de distribucion utilizando las librerias de **sns.countplot** y **plt** nos permite

# %%
sns.countplot(
    x='Generation',
    hue='Generation',
    data=pokemons,
    palette='nipy_spectral',
    legend=False
)

plt.title('Número de Pokémon agrupados por generación')
plt.show()

# %% [markdown]
# Text(0.5, 1.0, 'Number of pokemons grouped by generation')

# %% [markdown]
# ¿Cuantos Pokemones hay por cada tipo?

# %% [markdown]
# Recordemos que excluimos del data set la columna de type 2, po qe en este analisis conderamos

# %% [markdown]
# value_counts() cuenta la frecuencia de cada tipo de Pokémon y muestra los resultados ordenados de mayor a menor cantidad.

# %%
pokemons.['Type 1'].value_counts()
# Out:
# Type 1
# Water       114
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         46
# Electric     45
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(
    data=pokemons,
    x='Type',
    hue='Type',
    palette='twilight',
    legend=False
)
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.boxplot(data=pokemons.drop(['#','Total','Generation','Legendary'],axis=1),fliersize=3,palette='seismic')
plt.title('Boxplots for stats')
# Out:
# Text(0.5, 1.0, 'Boxplots for stats')

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=pokemons.drop(['#','Total','Generation','Legendary'],axis=1),palette='rocket')
plt.title('Violinplots for stats')
# Out:
# Text(0.5, 1.0, 'Violinplots for stats')

# %%
pokemons.groupby('Type').sum()
# Out:
#               #                                               Name  Total  \
# Type
# Bug       23080  CaterpieMetapodButterfreeWeedleKakunaBeedrillB...  26146
# Dark      14302  UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...  13818
# Dragon    15180  DratiniDragonairDragoniteAltariaAltariaMega Al...  17617
# Electric  16094  PikachuRaichuMagnemiteMagnetonVoltorbVoltorbEl...  19840
# Fairy      7642  ClefairyClefableCleffaTogepiTogeticSnubbullGra...   7024
# Fighting   9824  MankeyPrimeapeMachopMachokeMachampHitmonleeHit...  11244
# Fire      17025  CharmanderCharmeleonCharizardCharizardMega Cha...  23820
# Flying     2711  TornadusIncarnate FormeTornadusTherian FormeNo...   1940
# Ghost     15568  GastlyHaunterGengarGengarMega GengarMisdreavus...  14066
# Grass     24141  BulbasaurIvysaurVenusaurVenusaurMega VenusaurO...  29480
# Ground    11401  SandshrewSandslashDiglettDugtrioCuboneMarowakR...  14000
# Ice       10165  JynxArticunoSwinubPiloswineDelibirdSmoochumSno...  10403
# ...

# %%
pokemons.groupby('Type').sum().HP

# In this series the types are alphabetically ordered.
# Out:
# Type
# Bug         3925
# Dark        2071
# Dragon      2666
# Electric    2671
# Fairy       1260
# Fighting    1886
# Fire        3635
# Flying       283
# Ghost       2062
# Grass       4709
# Ground      2361
# Ice         1728
# Normal      7573
# Poison      1883
# Psychic     4026
# Rock        2986
# Steel       1761
# Water       8181
# Name: HP, dtype: int64

# %%
pokemons['Type'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# 21.- Ordenamos de tipo de pokemones por orden de lista

# %%
list_types=pokemons['Type'].unique().tolist() # Convert the array of types into a list
list_types.sort() # Sorting the list of strings alphabetically
list_types
# Out:
# ['Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water']

# %% [markdown]
# 22.-Calculando de los datos para graficar las estadisticas para cada tipo de pokemon, respetandos el orden alfabetico previamente definido

# %%
plt.style.use('ggplot')##Carga el estilo del contenedor del grafico
plt.style.use('seaborn-v0_8-darkgrid')

stats = pokemons[['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']]
k = 1
m = 0
palette = ['magma','ocean','vlag','copper','mako','winter']

plt.figure(figsize=(17, 17))

for i in stats:
    plt.subplot(3, 2, k)
    k = k + 1
    # Agregamos hue=list_types y legend=False para evitar el FutureWarning
    sns.barplot(x=pokemons.groupby('Type').sum()[i], y=list_types, hue=list_types, palette=palette[m], legend=False)
    m = m + 1
    plt.title('Total of ' + i)

# %%
**Ejercicio 6: ** modificacion al Data original, para verificar  el calculo de graficos dinamicos

    Actividades:
-Agregar una nueva estadistica denominada "Armor" (Armadura)
-Modificar el Dataset original (pokemon.csv) con valores sugeridos por la IA
-Documentar la estadistica en la actividad (6)
-Agregar 5 nuevos pokemones de una nueva categoria denominada"Artificial"
-Modificar los parametros necesarios para graficacion
-Recalcular los graficos

# %%
plt.figure(figsize(15,30)
for k start in enumrable(status, columns, start=1);

    plt.subplot(0,1,k
