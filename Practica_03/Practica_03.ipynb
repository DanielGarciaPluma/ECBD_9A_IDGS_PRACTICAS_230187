# %% [markdown]
# # Practica 03: Análisis de Datos Exploratorio con Python y Jupiter Notebook
# **Programa de Estudios:** Ingeniería en Desarrollo y Gestión de Software \
# **Asignatura:** Extracción de Conocimiento en Base de Datos \
# **Docente:** M.T.I. Marco A. Ramírez Hernández \
# **Periodo:** Mayo - Agosto 2026

# %% [markdown]
# ## Unidad 2: Preparación de los Datos

# %% [markdown]
# **Nombre del Estudiante:** Carlos Daniel Garcia Pluma \
# **Matricula:** 230187 \
# **Grado y Grupo:** 9°A IDGS
# ***

# %% [markdown]
# El estudiante practicará como realizar un análisis exploratorio de datos, utilizando el lenguaje de programación de Python, y librerías comúnes para la
# carga, manipulación, análisis y visualización previa de un conjunto de datos (Dataset), para esta práctica se utilizarán las librerías de:
# - Pandas
# - Numpy
# - Seaborn
# - OS
# - Matplotlib

# %% [markdown]
# ## 1. Importar las librerías necesarias para realizar el EDA
#
# Comenzamos por importar la librería que nos permitirá manipular los datos del dataset extraidos de una fuente de datos (datasource)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## 2. Creamos un DataFrame, leyendo el archivo delimitado por comas (.CSV)

# %%
pokemons = pd.read_csv('./Pokemon.csv')

# %% [markdown]
# ## 3. Imprimimos el resultado de lectura
#
# Este comando imprime en una tabla las columnas y las filas del dataframe, siempre de manera estándar nos mostrará los primeros 5 y los últimos 5 registro del Dataframe

# %%
pokemons
# Out:
#          #                   Name      Type 1  Type 2  Total    HP  Attack  \
# 0      1.0              Bulbasaur       Grass  Poison  318.0  45.0    49.0
# 1      2.0                Ivysaur       Grass  Poison  405.0  60.0    62.0
# 2      3.0               Venusaur       Grass  Poison  525.0  80.0    82.0
# 3      3.0  VenusaurMega Venusaur       Grass  Poison  625.0  80.0   100.0
# 4      4.0             Charmander        Fire     NaN  309.0  39.0    52.0
# ..     ...                    ...         ...     ...    ...   ...     ...
# 797  722.0               Synthbit  Artificial     NaN  395.0  65.0    60.0
# 798  723.0               Synthlet  Artificial     NaN  510.0  75.0    72.0
# 799  724.0               Synthrex  Artificial     NaN  545.0  80.0    90.0
# 800  725.0              Synthagon  Artificial     NaN  535.0  88.0   118.0
# 801  726.0             Syntharion  Artificial     NaN  590.0  95.0   105.0
#
# ...

# %% [markdown]
# ## 4. Obtener una muestra aleatoria de registros del dataframe usando elmétodo **.sample**
#
# Como parámetro de entrada podemos definir un entero que determina el tamaño de la muestra

# %%
pokemons.sample(7) ## Obtiene una  muestra de 7 pokemones aleatoria
# Out:
#          #                Name    Type 1 Type 2  Total     HP  Attack  \
# 709  646.0  KyuremWhite Kyurem    Dragon    Ice  700.0  125.0   120.0
# 581  525.0             Boldore      Rock    NaN  390.0   70.0   105.0
# 310  288.0            Vigoroth    Normal    NaN  440.0   80.0    80.0
# 175  162.0              Furret    Normal    NaN  415.0   85.0    76.0
# 69    64.0             Kadabra   Psychic    NaN  400.0   40.0    35.0
# 89    82.0            Magneton  Electric  Steel  465.0   50.0    60.0
# 42    37.0              Vulpix      Fire    NaN  299.0   38.0    41.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary  Evolution_Level
# 709     90.0    170.0    100.0   95.0         5.0      True              2.0
# 581    105.0     50.0     40.0   20.0         5.0     False              2.0
# 310     80.0     55.0     55.0   90.0         3.0     False              2.0
# 175     64.0     45.0     55.0   90.0         2.0     False              2.0
# ...

# %% [markdown]
# **Ejercicio 1:** Obtén una muestra de 50
#
# ```pokemons_50 = pokemons.sample(50)```

# %% [markdown]
# ## 5. Obtener una muestra de rangos definidos usando **.iloc**

# %%
pokemons_100_to_200 = pokemons.iloc[100:200]
pokemons_100_to_200
# Out:
#          #                   Name    Type 1  Type 2  Total     HP  Attack  \
# 100   93.0                Haunter     Ghost  Poison  405.0   45.0    50.0
# 101   94.0                 Gengar     Ghost  Poison  500.0   60.0    65.0
# 102   94.0      GengarMega Gengar     Ghost  Poison  600.0   60.0    65.0
# 103   95.0                   Onix      Rock  Ground  385.0   35.0    45.0
# 104   96.0                Drowzee   Psychic     NaN  328.0   60.0    48.0
# ..     ...                    ...       ...     ...    ...    ...     ...
# 195  181.0  AmpharosMega Ampharos  Electric  Dragon  610.0   90.0    95.0
# 196  182.0              Bellossom     Grass     NaN  490.0   75.0    80.0
# 197  183.0                 Marill     Water   Fairy  250.0   70.0    20.0
# 198  184.0              Azumarill     Water   Fairy  420.0  100.0    50.0
# 199  185.0              Sudowoodo      Rock     NaN  410.0   70.0   100.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary  Evolution_Level
# ...

# %% [markdown]
# ## 6. Como saber las columnas o atributos que tiene el Dataframe

# %%
pokemons.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary',
#        'Evolution_Level'],
#       dtype='object')

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th>Campo</th>
#             <th>Descripcion</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <strong>#</strong>:
#             </td>
#             <td>
#                 El ID o número de identificación del Pokemon.
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <strong>Name</strong>:
#             </td>
#             <td>
#                 El nombre del Pokémon.
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <strong>Type 1<strong>:
#             </td>
#             <td>
#                 Se refiere a las propiedades elementales (tipos) asociadas tanto al Pokémon como a sus movimientos.
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <strong>Type 2</strong>:
#             </td>
#             <td>
#                 Los Pokémon pueden tener hasta dos tipos (Pokémon de tipo Dual); los movimientos solo pueden tener uno.
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <strong>Total</strong>:
#             </td>
#             <td>
#                 Representa la suma de todos los stats, lo que te da una idea de qué tan "pesado" o fuerte es el Pokémon
#             </td>
#         </tr>
#         <tr>
#         <td>
#                 <strong>HP</strong>:
#             </td>
#             <td> (Puntos de Salud) Es qué tanto aguante tiene un Pokémon antes de que lo dejen fuera de combate (se desmaye)
#         </tr>
#         <tr>
#         <td>
#                 <strong>Attack</strong>:
#             </td>
#             <td> La fuerza de los ataques físicos del Pokemon
#         </tr>
#         <tr>
#         <td>
#                 <strong>Defense</strong>:
#             </td>
#             <td> Qué tanto aguanta el pPokémon contra los ataques físicos del rival
#         </tr>
#                     <td>
#                 <strong>Evolution_Level</strong>:
#             </td>
#             <td> Nivel de Evolución del Pokémon
#         </tr>
#         <tr>
#         <td>
#                 <strong>Sp. Atk</strong>:
#             </td>
#             <td> Ataque Especial; el poder de los movimientos especiales del Pokémon
#         </tr>
#         <tr>
#             <td>
#                 <strong>Sp.Def</strong>:
#             </td>
#             <td>
#                 Defense Especial; Qué tan resistente es el Pokémon ante los ataques especiales
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <strong>Speed</strong>:
#             </td>
#             <td>
#                 Velocidad; el Pokémon que tenga más velocidad es el que ataca primero
#             </td>
#         </tr>
#         <tr>
#             <td><strong>
#                 Generation
#             </strong></td>
#             <td>
#                 Generacion; Se refiere a la generación de la serie de juegos a la que pertenece
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <strong>Legendary</strong>:
#             </td>
#             <td>
#                 Indica si el Pokémon es Legendario o no (son bichos muy raros y poderosos). Es un valor booleano (sí/no)
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## 7. Explorar la composición y ausencia de datos (METADATA) con **.info**
#
# La libreria de pandas, incluye un método que nos permite evaluyar el tipo de dato y su composición y ausencia.

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 802 entries, 0 to 801
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   #                801 non-null    float64
#  1   Name             801 non-null    object
#  2   Type 1           801 non-null    object
#  3   Type 2           413 non-null    object
#  4   Total            801 non-null    float64
#  5   HP               801 non-null    float64
#  6   Attack           801 non-null    float64
#  7   Defense          801 non-null    float64
#  8   Sp. Atk          801 non-null    float64
#  9   Sp. Def          801 non-null    float64
#  10  Speed            801 non-null    float64
#  11  Generation       801 non-null    float64
#  12  Legendary        801 non-null    object
#  13  Evolution_Level  801 non-null    float64
# dtypes: float64(10), object(4)
# memory usage: 87.8+ KB

# %% [markdown]
# ## 8. Limpieza de Datos.
#
# Dependiendo del objeto del análisis algunas columnas o registro no serán necesarias en nuestro Dataframe, en este caso omitiremos los datos vacios, por los que eliminaremos la columna 'Type 2', y renombraremos la columna 'Type 1' por 'Type'.

# %%
del pokemons['Type 2']
pokemons.rename(columns={'Type 1':'Type'}, inplace= True)

# %%
pokemons
# Out:
#          #                   Name        Type  Total    HP  Attack  Defense  \
# 0      1.0              Bulbasaur       Grass  318.0  45.0    49.0     49.0
# 1      2.0                Ivysaur       Grass  405.0  60.0    62.0     63.0
# 2      3.0               Venusaur       Grass  525.0  80.0    82.0     83.0
# 3      3.0  VenusaurMega Venusaur       Grass  625.0  80.0   100.0    123.0
# 4      4.0             Charmander        Fire  309.0  39.0    52.0     43.0
# ..     ...                    ...         ...    ...   ...     ...      ...
# 797  722.0               Synthbit  Artificial  395.0  65.0    60.0     70.0
# 798  723.0               Synthlet  Artificial  510.0  75.0    72.0     90.0
# 799  724.0               Synthrex  Artificial  545.0  80.0    90.0     95.0
# 800  725.0              Synthagon  Artificial  535.0  88.0   118.0     70.0
# 801  726.0             Syntharion  Artificial  590.0  95.0   105.0     88.0
#
# ...

# %% [markdown]
# **Ejercicio 02:** Consulta la Metadata de la actualización y compara los cambios con la anterior.
#
# ¿Qué cambios ves? Redacta tu respuesta

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 802 entries, 0 to 801
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   #                801 non-null    float64
#  1   Name             801 non-null    object
#  2   Type             801 non-null    object
#  3   Total            801 non-null    float64
#  4   HP               801 non-null    float64
#  5   Attack           801 non-null    float64
#  6   Defense          801 non-null    float64
#  7   Sp. Atk          801 non-null    float64
#  8   Sp. Def          801 non-null    float64
#  9   Speed            801 non-null    float64
#  10  Generation       801 non-null    float64
#  11  Legendary        801 non-null    object
#  12  Evolution_Level  801 non-null    float64
# dtypes: float64(10), object(3)
# memory usage: 81.6+ KB

# %% [markdown]
# **Cambios**: Cambia el número de columnas del Dataframe. Esto se puede corroborar viendo el contador de la primera columna; el último numero es 11, cuando antes era 12. Igual la columna 'Type' es un renombre de la anterior llamada 'Type 1'. La columna 'Type 2' desaparecio.

# %% [markdown]
# ## 9. Visualización de los primeros datos usando el método **.head**.

# %%
pokemons.head()
# Out:
#      #                   Name   Type  Total    HP  Attack  Defense  Sp. Atk  \
# 0  1.0              Bulbasaur  Grass  318.0  45.0    49.0     49.0     65.0
# 1  2.0                Ivysaur  Grass  405.0  60.0    62.0     63.0     80.0
# 2  3.0               Venusaur  Grass  525.0  80.0    82.0     83.0    100.0
# 3  3.0  VenusaurMega Venusaur  Grass  625.0  80.0   100.0    123.0    122.0
# 4  4.0             Charmander   Fire  309.0  39.0    52.0     43.0     60.0
#
#    Sp. Def  Speed  Generation Legendary  Evolution_Level
# 0     65.0   45.0         1.0     False              2.0
# 1     80.0   60.0         1.0     False              3.0
# 2    100.0   80.0         1.0     False              3.0
# 3    120.0   80.0         1.0     False              4.0
# 4     50.0   65.0         1.0     False              2.0

# %% [markdown]
# **Ejercicio 03**: Muestra los últimos 10 registros del Dataframe

# %%
pokemons.tail(10)
# Out:
#          #                 Name        Type  Total    HP  Attack  Defense  \
# 792  719.0  DiancieMega Diancie        Rock  700.0  50.0   160.0    110.0
# 793  720.0  HoopaHoopa Confined     Psychic  600.0  80.0   110.0     60.0
# 794  720.0   HoopaHoopa Unbound     Psychic  680.0  80.0   160.0     60.0
# 795  721.0            Volcanion        Fire  600.0  80.0   110.0    120.0
# 796    NaN                  NaN         NaN    NaN   NaN     NaN      NaN
# 797  722.0             Synthbit  Artificial  395.0  65.0    60.0     70.0
# 798  723.0             Synthlet  Artificial  510.0  75.0    72.0     90.0
# 799  724.0             Synthrex  Artificial  545.0  80.0    90.0     95.0
# 800  725.0            Synthagon  Artificial  535.0  88.0   118.0     70.0
# 801  726.0           Syntharion  Artificial  590.0  95.0   105.0     88.0
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary  Evolution_Level
# 792    160.0    110.0  110.0         6.0      True              4.0
# ...

# %% [markdown]
# ## 10. Estadística básica del Dataframe
#
# Pandas permite emitir un reporte de estadística básica (medidas de tendencia) sobre datos cuantitativos usando el comando **.describe**.

# %%
pokemons.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  801.000000  801.000000  801.000000  801.000000  801.000000  801.000000
# mean   365.016230  435.220974   69.293383   79.033708   73.860175   72.832709
# std    209.668181  119.930229   25.534928   32.450233   31.168019   32.681982
# min      1.000000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    186.000000  330.000000   50.000000   55.000000   50.000000   50.000000
# 50%    367.000000  450.000000   65.000000   75.000000   70.000000   65.000000
# 75%    543.000000  515.000000   80.000000  100.000000   90.000000   95.000000
# max    726.000000  780.000000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation  Evolution_Level
# count  801.000000  801.000000  801.000000       801.000000
# mean    71.937578   68.247191    3.328340         2.123596
# std     27.826266   29.046322    1.665325         0.525314
# ...

# %% [markdown]
# ## 11. Calcular el total de datos no duplicados (únicos)
#
# Usaremos **.len()** como función para calcular la longitud del dataframe y **.unique()** para excluir los duplicados.
#
# ***NOTA:*** No considerar ID como un atributo de llave primaria, sino el total de columnas como un solo elemento u objeto.

# %% [markdown]
# Obteniendo los valores unicos por columna en este caso en la columna "Name"

# %%
len(pokemons.Name.unique())
# Out:
# 802

# %% [markdown]
# Obteniendo el total de objetos (conjunto de atributos, estrictamente iguales) únicos

# %%
total_unicos = len(pokemons.drop_duplicates())
total_unicos
# Out:
# 802

# %% [markdown]
# **Ejercicio 04:** Obtener el total de IDs únicos en el dataset

# %%
len(pokemons["#"].unique())
# Out:
# 723

# %% [markdown]
# **Ejercicio 05:** Obtener el total de tipos únicos de pokemones

# %%
len(pokemons.Type.unique())
# Out:
# 20

# %% [markdown]
# ## 12. Contabilización de Datos por Atributo
#
# Pandas nos permite agrupar los datos por atributo y contabilizar los totales usando **.value_counts()**
#
# ¿Cuántos Pokémones hay por generación?

# %%
pokemons['Generation'].value_counts()
# Out:
# Generation
# 1.0    166
# 5.0    165
# 3.0    160
# 4.0    121
# 2.0    106
# 6.0     82
# 7.0      1
# Name: count, dtype: int64

# %% [markdown]
# ## 13. Graficado de número de pokemones agrupados por el atributo **Generation**
#
# El método **countplot** ofrece un constructor donde se puede configurar la gráfica.
#
# La libreria de **Matplot** (nombrada plt), permite poner un texto de título.
#
# ¿Cuántos pokemones hay por generación?

# %%
sns.countplot(x='Generation', hue="Generation", data=pokemons,palette='nipy_spectral')
plt.title('Número de pokemones agrupados por el atributo de Generacion')
# Out:
# Text(0.5, 1.0, 'Número de pokemones agrupados por el atributo de Generacion')

# %% [markdown]
# ## 14. Conteo de pokemones por el atributo **Tipo**
#
# Utilizamos **.value_counts()** para realizar un conteo de los valores especificados en el atributo accedido anterior (Type), permitiendo hacer un conteo de las apariciones de ellos.

# %%
pokemons.Type.value_counts()
# Out:
# Type
# Water         112
# Normal         95
# Grass          70
# Bug            68
# Psychic        57
# Fire           52
# Electric       44
# Rock           44
# Dragon         32
# Ground         32
# Ghost          32
# Dark           31
# Poison         28
# Steel          27
# Fighting       27
# Ice            24
# Fairy          17
# Artificial      5
# Flying          4
# Name: count, dtype: int64

# %% [markdown]
# ## 15. Conteo de pokemones por el atributo **Tipo** (Graficado)
#
# Se usa la libreria **matplot** para configurar el tamaño de la gráfica.
#
# **NOTA**: _Por el numero de pokemones de tipo Agua y Normal es alto comparado al resto, los pokemones respectivos tendran siempre un total de stats mas alto._

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=pokemons.Type, hue=pokemons.Type, palette='twilight', legend=False)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %% [markdown]
# ## 16. Revisar distribución de estadísticas con **boxplot**.
#
# Se configura el estilo de la gráfica con el metodo **.set_style**.
#
# Además, se utiliza como data el Dataframe de pokemons, pero excluyendo las columnas: **#**, **Total**, **Generation** y **Legendary**

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.boxplot(data=pokemons.drop(['#','Total','Generation','Legendary'],axis=1),fliersize=3,palette='seismic')
plt.title('Boxplots para Estadísticas')
# Out:
# Text(0.5, 1.0, 'Boxplots para Estadísticas')

# %% [markdown]
# 17. Revisar distribución de estadísticas con **violinplot**.
#
# Se grafican los mismos datos del punto anterior, pero con una gráfica y paleta de colores diferentes.

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=pokemons.drop(['#','Total','Generation','Legendary'],axis=1),palette='rocket')
plt.title('Violinplots para Estadísticas')
# Out:
# Text(0.5, 1.0, 'Violinplots para Estadísticas')

# %% [markdown]
# 18. Pokemones agrupados por el atributo **Tipo**.
#
# Se utilizan los métodos **.groupby()** y **.sum()**

# %%
pokemons.groupby('Type').sum()
# Out:
#                   #                                               Name  \
# Type
# Artificial   3620.0        SynthbitSynthletSynthrexSynthagonSyntharion
# Bug         22431.0  CaterpieMetapodButterfreeWeedleKakunaBeedrillB...
# Dark        14302.0  UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...
# Dragon      15180.0  DratiniDragonairDragoniteAltariaAltariaMega Al...
# Electric    15994.0  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...
# Fairy        7642.0  ClefairyClefableCleffaTogepiTogeticSnubbullGra...
# Fighting     9824.0  MankeyPrimeapeMachopMachokeMachampHitmonleeHit...
# Fire        17025.0  CharmanderCharmeleonCharizardCharizardMega Cha...
# Flying       2711.0  TornadusIncarnate FormeTornadusTherian FormeNo...
# Ghost       15568.0  GastlyHaunterGengarGengarMega GengarMisdreavus...
# Grass       24141.0  BulbasaurIvysaurVenusaurVenusaurMega VenusaurO...
# Ground      11401.0  SandshrewSandslashDiglettDugtrioCuboneMarowakR...
# ...

# %% [markdown]
# ## 19. Pokemones agrupados por el atributo tipo, ordenados en orden alfabético.
#
# Se accede al atributo HP, lo cual permite visualizar el Tipo, y el HP del Pokemon.

# %%
pokemons.groupby('Type').sum().HP
# Out:
# Type
# Artificial     403.0
# Bug           3854.0
# Dark          2071.0
# Dragon        2666.0
# Electric      2631.0
# Fairy         1260.0
# Fighting      1886.0
# Fire          3635.0
# Flying         283.0
# Ghost         2062.0
# Grass         4709.0
# Ground        2361.0
# Ice           1728.0
# Normal        7338.0
# Poison        1883.0
# Psychic       4026.0
# Rock          2876.0
# Steel         1761.0
# Water         8071.0
# Name: HP, dtype: float64

# %% [markdown]
# ## 20. Listado de todos los tipos de Pokemones (Sin datos duplicados)

# %%
pokemons['Type'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', nan, 'Artificial'],
#       dtype=object)

# %% [markdown]
# 21. Ordenamiento de Tipos (Type) por orden alfabético
# Convierte el arreglo de tipos en una lista para aplicar ordenamiento
# Ordena los elementos de forma ascendente por defecto

# %%
list_types = pokemons['Type'].dropna().unique().tolist()
list_types.sort()

list_types
# Out:
# ['Artificial',
#  'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water']

# %% [markdown]
# ## 22. Calculando los datos para graficación del total de estadísticas por cada tipo de Pokémon, respetano el orden alfabético previamente definido.

# %% [markdown]
# Se aplica un estilo de gráficos accesible y se agrupan los datos de Pokémon por tipo para sumar sus \
# estadísticas principales. Luego se generan varios gráficos de barras en una cuadrícula,\
# donde se comparan las estadísticas (HP, Attack, Defense, etc.) entre tipos usando diferentes paletas de colores.

# %%
plt.style.use('tableau-colorblind10') 

stats=['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']
palettes = ['magma','ocean','vlag','copper','mako','winter']
pokemon_stats = pokemons.groupby('Type')[stats].sum()

plt.figure(figsize=(17,17))

for k, stat in enumerate(stats, start=1):
    plt.subplot(3,2,k)
    
    sns.barplot(
        x=pokemon_stats[stat],
        y=pokemon_stats.index,
        hue=pokemon_stats.index, 
        palette=palettes[k-1],
        legend=False
    )
    plt.title(f'Total de {stat}')
    plt.xlabel(stat)
    plt.ylabel('Type')

plt.show()

# %% [markdown]
# **Ejercicio 06**: Modificación al Dataset Original, para verificar el cálculo de gráficos dinámicos.
#
# <h4>Actividades</h4>
#
# 1. Agregar una nueva estadística denominada "Evolution_Level" (Nivel de Evolución).
# 2. Modificar el Dataset original (pokemon.csv) con valores sugeridos por la IA.
# 3. Documentar la estadística en la actividad 6.
# 4. Agregar 5 nuevos pokémones de una nueva categoría denominada "Artificial".
# 5. Modificar los parámetros necesarios para la gráficación.
# 6. Recalcular los gráficos.

# %% [markdown]
# Se aplica un estilo de gráficos accesible y se agrupan los datos de Pokémon por tipo para sumar sus \
# estadísticas principales, incluyendo el nivel de evolución. Después, se generan gráficos de barras que \
# comparan cada estadística entre los diferentes tipos de Pokémon, utilizando una paleta de colores distinta\
# para cada gráfico.

# %%
plt.style.use('tableau-colorblind10')

stats=['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Evolution_Level']
palettes = ['magma','ocean','vlag','copper','mako','winter','plasma']
pokemon_stats = pokemons.groupby('Type')[stats].sum()

plt.figure(figsize=(15,30))

for k, stat in enumerate(stats, start=1):
    plt.subplot(4,2,k)
    
    sns.barplot(
        x=pokemon_stats[stat],
        y=pokemon_stats.index,
        hue=pokemon_stats.index, 
        palette=palettes[k-1],
        legend=False
    )
    plt.title(f'Total de {stat}')
    plt.xlabel(stat)
    plt.ylabel('Type')

plt.show()

# %% [markdown]
# ## 23. Visualización con Swarmplots
# Se crea una figura que contiene varios gráficos de dispersión, uno para cada estadística de los Pokémon. Mediante un ciclo, se comparan los valores de cada estadística según el tipo de Pokémon, utilizando diferentes colores y una ligera separación entre los puntos para evitar que se sobrepongan. Finalmente, se ajusta la distribución de los gráficos para mejorar su visualización y se muestran en pantalla.

# %%
plt.figure(figsize=(15,30))

for k, stat in enumerate(stats, start=1):
    plt.subplot(7,1,k)

    sns.stripplot(
        data=pokemons,
        x='Type',
        y=stat,
        hue='Type',
        palette='Dark2',
        legend=False,
        jitter=True
    )

    plt.title(f'Total de {stat} para cada tipo')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 24. Plots para cada tipo de Pokemon
#
# Este código genera una cuadrícula de gráficos de barras, donde cada gráfico representa un tipo de Pokémon. En cada uno se suman las estadísticas de todos los Pokémon de ese tipo y se muestran en un gráfico horizontal con una paleta de colores. Además, se establece un mismo límite en el eje X para facilitar la comparación entre los diferentes tipos de Pokémon.

# %%
k=1;
plt.figure(figsize=(17,25))
for i in list_types:
    plt.subplot(7,3,k);   
    k=k+1; 
    type_data = pokemons[pokemons.Type == i].sum(numeric_only=True)
    pokemon_stats = type_data.drop(['#', 'Generation', 'Legendary', 'Total'], errors='ignore')
    
    sns.barplot(
        x=pokemon_stats.values,
        y=pokemon_stats.index,
        hue=pokemon_stats.index,
        palette='inferno',
        legend=False
    )
    
    plt.title(i)
    plt.xlim(0,8500)

# %% [markdown]
# ## 25. Preparación de Datos para graficado de Pokemons
#
# Se utiliza el método .melt() para "derretir" las columnas especificadas en rows.

# %%
pok_melt=pd.melt(pokemons,id_vars=['Name','Type','Legendary'],value_vars=['HP','Defense','Attack','Sp. Atk','Sp. Def','Speed','Evolution_Level'])
pok_melt.head()
# Out:
#                     Name   Type Legendary variable  value
# 0              Bulbasaur  Grass     False       HP   45.0
# 1                Ivysaur  Grass     False       HP   60.0
# 2               Venusaur  Grass     False       HP   80.0
# 3  VenusaurMega Venusaur  Grass     False       HP   80.0
# 4             Charmander   Fire     False       HP   39.0

# %% [markdown]
# ## 26. Graficado con Swarmplots
#
# Genera una cuadrícula de gráficos de dispersión tipo swarmplot, donde cada gráfico corresponde a un tipo de Pokémon. En ellos se muestran los valores de las distintas estadísticas de cada Pokémon, utilizando colores para diferenciarlas. Además, se añade una ligera variación a los datos para evitar la superposición de puntos y mejorar la visualización, ocultando también las advertencias innecesarias de la librería Seaborn.

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='seaborn')

plt.figure(figsize=(17,25))
k=1

for i in list_types:
    plt.subplot(10, 2, k)
    k = k + 1

    type_melted = pok_melt[pok_melt.Type == i].copy()
    
    if type_melted.empty:
        continue
    
    np.random.seed(42)
    type_melted['value'] = type_melted['value'] + np.random.uniform(-0.1, 0.1, size=len(type_melted))
    
    sns.swarmplot(
        data=type_melted, 
        x='variable', 
        y='value', 
        hue='variable',       
        palette='gist_stern',
        legend=False,          
        size=1.5,             
        alpha=0.7             
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 27. Promedio de la estadísticas agrupadas por el tipo de Pokemon.
#
# Se instancia un Dataframe y se le asignan los datos correspondientes a el promedio de todas las estadísticas, acorde al tipo de Pokemon (agrupadas en base al tipo)

# %%
df = pd.DataFrame()
for i in stats:
	df[i]=pokemons.groupby('Type').describe()[i]['mean']

df
# Out:
#                    HP      Attack     Defense     Sp. Atk    Sp. Def  \
# Type
# Artificial  80.600000   89.000000   82.600000  105.600000  88.000000
# Bug         56.676471   70.250000   70.367647   52.897059  64.352941
# Dark        66.806452   88.387097   70.225806   74.645161  69.516129
# Dragon      83.312500  112.125000   86.375000   96.843750  88.843750
# Electric    59.795455   69.090909   66.295455   90.022727  73.704545
# Fairy       74.117647   61.529412   65.705882   78.529412  84.705882
# Fighting    69.851852   96.777778   65.925926   53.111111  64.703704
# Fire        69.903846   84.769231   67.769231   88.980769  72.211538
# Flying      70.750000   78.750000   66.250000   94.250000  72.500000
# Ghost       64.437500   73.781250   81.187500   79.343750  76.468750
# Grass       67.271429   73.214286   70.800000   77.500000  70.428571
# Ground      73.781250   95.750000   84.843750   56.468750  62.750000
# ...

# %% [markdown]
# ## 28. Graficado de promedio de cada estadística por cada tipo
#
# Este código crea una serie de gráficos de barras que muestran el **promedio de cada estadística** de los Pokémon por tipo. Mediante un ciclo, genera un gráfico para cada atributo, utilizando una paleta de colores diferente y agregando títulos y etiquetas para facilitar la comparación de los valores promedio entre los distintos tipos de Pokémon.

# %%
plt.figure(figsize=(16,35))
k=1
m=0
for i in stats:
    plt.subplot(4,2,k)
    k=k+1
    sns.barplot(x=df[i],hue=df.index,palette=palettes[m])
    m=m+1
    plt.title(str('Promedio del total de ')+ i +str(' para cada tipo'))
    plt.xlabel(i)

# %% [markdown]
# ## 29. Graficado de tipos de pokemones y sus estadísticas
#
# Este código genera una cuadrícula de gráficos de barras donde se muestra el **promedio de las estadísticas** para cada tipo de Pokémon. Cada gráfico utiliza una misma escala y una paleta de colores para facilitar la comparación entre tipos.

# %%
k=1;
plt.figure(figsize=(16,25))
for i in list_types:
    plt.subplot(7,3,k);
    k=k+1;
    sns.barplot(x=df.loc[i,:].values,hue=df.loc[i,:].index, palette='Paired');
    plt.title(i)
    plt.xlim(0,130)
    plt.ylabel('Mean')
plt.show()

# %% [markdown]
# ## 30. Ordenamiento descendiente

# %% [markdown]
# Este código genera una **gráfica de barras** que muestra la suma de las estadísticas totales de los Pokémon por tipo, ordenadas de mayor a menor y con un título descriptivo.

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=pokemons.groupby('Type').sum().Total.sort_values(ascending=False).index
            ,y=pokemons.groupby('Type').sum().Total.sort_values(ascending=False),
            hue=pokemons.groupby('Type').sum().Total.sort_values(ascending=False).index 
            ,legend=False, palette='cool')
plt.title('Total de todas las estadísticas para cada tipo de Pokemon')
# Out:
# Text(0.5, 1.0, 'Total de todas las estadísticas para cada tipo de Pokemon')

# %% [markdown]
# ## 31. Media de todas las estadísticas para cada tipo de Pokemon
#
# Se grafica con barplot la media de todas las estadísticas, para cada tipo de Pokemon en el Dataset. La gráfica se muestra en orden descendente

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=pokemons.groupby('Type')["Total"].mean().sort_values(ascending=False).index,
            y=pokemons.groupby('Type')["Total"].mean().sort_values(ascending=False).values,
            hue=pokemons.groupby('Type')["Total"].mean().sort_values(ascending=False).index,
            legend=False,palette='twilight_shifted')
plt.title('Promedio del total de todas las estadísticas para cada tipo de Pokemon')
# Out:
# Text(0.5, 1.0, 'Promedio del total de todas las estadísticas para cada tipo de Pokemon')

# %% [markdown]
# ## 32. Cuál es la mejor estadística para cada tipo?

# %% [markdown]
# Este código busca, para cada tipo de Pokémon, la **estadística más alta (mejor atributo)** y luego la imprime indicando cuál es y a qué tipo pertenece.

# %%
best_stats = []
for i in list_types:
    best_stats.append(df.loc[i,:].sort_values(ascending=False).index[0])
m=0
for k in best_stats:
    print('Best stat of type ',list_types[m],' is ',k)
    m=m+1
# Out:
# Best stat of type  Artificial  is  Sp. Atk
# Best stat of type  Bug  is  Defense
# Best stat of type  Dark  is  Attack
# Best stat of type  Dragon  is  Attack
# Best stat of type  Electric  is  Sp. Atk
# Best stat of type  Fairy  is  Sp. Def
# Best stat of type  Fighting  is  Attack
# Best stat of type  Fire  is  Sp. Atk
# Best stat of type  Flying  is  Speed
# Best stat of type  Ghost  is  Defense
# Best stat of type  Grass  is  Sp. Atk
# Best stat of type  Ground  is  Attack
# Best stat of type  Ice  is  Sp. Atk
# Best stat of type  Normal  is  HP
# Best stat of type  Poison  is  Attack
# Best stat of type  Psychic  is  Sp. Atk
# Best stat of type  Rock  is  Defense
# Best stat of type  Steel  is  Defense
# Best stat of type  Water  is  Sp. Atk

# %% [markdown]
# ## 33. Pokémon con evolución mega NIVEL 4
#
# Los Pokémon de evolución nivel 4 son aquellos que contienen la palabra **“mega”** en su nombre.

# %%
pokemons[pokemons.Evolution_Level==4]
# Out:
#          #                       Name        Type  Total     HP  Attack  \
# 3      3.0      VenusaurMega Venusaur       Grass  625.0   80.0   100.0
# 7      6.0  CharizardMega Charizard X        Fire  634.0   78.0   130.0
# 8      6.0  CharizardMega Charizard Y        Fire  634.0   78.0   104.0
# 12     9.0    BlastoiseMega Blastoise       Water  630.0   79.0   103.0
# 19    15.0      BeedrillMega Beedrill         Bug  495.0   65.0   150.0
# 23    18.0        PidgeotMega Pidgeot      Normal  579.0   83.0    80.0
# 71    65.0      AlakazamMega Alakazam     Psychic  590.0   55.0    50.0
# 87    80.0        SlowbroMega Slowbro       Water  590.0   95.0    75.0
# 102   94.0          GengarMega Gengar       Ghost  600.0   60.0    65.0
# 124  115.0  KangaskhanMega Kangaskhan      Normal  590.0  105.0   125.0
# 137  127.0          PinsirMega Pinsir         Bug  600.0   65.0   155.0
# 141  130.0      GyaradosMega Gyarados       Water  640.0   95.0   155.0
# ...

# %% [markdown]
# ## 34. Fix de Nombre Duplicado en Pokemones Mega
#
# Como se puede observar, en el resultado anterior, los pokemones con 'Mega' en el nombre, tienen el nombre duplicado despues de Mega.

# %%
mega_pokemons = [
    'Mega' + poke.split('Mega')[1]
    for poke in pokemons[pokemons.Evolution_Level == 4].Name
    if 'Mega' in poke
]

mega_pokemons
# Out:
# ['Mega Venusaur',
#  'Mega Charizard X',
#  'Mega Charizard Y',
#  'Mega Blastoise',
#  'Mega Beedrill',
#  'Mega Pidgeot',
#  'Mega Alakazam',
#  'Mega Slowbro',
#  'Mega Gengar',
#  'Mega Kangaskhan',
#  'Mega Pinsir',
#  'Mega Gyarados',
#  'Mega Aerodactyl',
#  'Mega Mewtwo X',
#  'Mega Mewtwo Y',
#  'Mega Ampharos',
#  'Mega Steelix',
#  'Mega Scizor',
#  'Mega Heracross',
#  'Mega Houndoom',
#  'Mega Tyranitar',
#  'Mega Sceptile',
#  'Mega Blaziken',
#  'Mega Swampert',
#  'Mega Gardevoir',
#  'Mega Sableye',
#  'Mega Mawile',
#  'Mega Aggron',
#  'Mega Medicham',
#  'Mega Manectric',
#  'Mega Sharpedo',
#  'Mega Camerupt',
#  'Mega Altaria',
#  'Mega Banette',
#  'Mega Absol',
#  'Mega Glalie',
#  'Mega Salamence',
#  'Mega Metagross',
#  'Mega Latias',
#  'Mega Latios',
#  'Mega Rayquaza',
#  'Mega Lopunny',
#  'Mega Garchomp',
#  'Mega Lucario',
#  'Mega Abomasnow',
#  'Mega Gallade',
#  'Mega Audino',
#  'Mega Diancie']

# %% [markdown]
# ## 35. Mejor tipo de Pokemon para cada estadística y modificación de Dataframe de Pokemones
#
# Similar al punto 32, pero esta vez se toma el Pokemón con la mejor estadística (acorde al tipo). Además, se modifico el Dataframe oiginal, con los nombres actuales en el Dataframe anterior (solo se modificaron  los pokemones con Evolution Level de 4)

# %%
for n in list_types:
    print('TYPE ' + n.upper())

    subset = pokemons[pokemons.Type == n]

    if subset.empty:
        continue

    for i in stats:
        name = subset.sort_values(by=i, ascending=False).iloc[0]['Name']
        print(f'Best {i} pokemon is {name}')

    print('*********************')
# Out:
# TYPE ARTIFICIAL
# Best HP pokemon is Syntharion
# Best Attack pokemon is Synthagon
# Best Defense pokemon is Synthrex
# Best Sp. Atk pokemon is Synthagon
# Best Sp. Def pokemon is Syntharion
# Best Speed pokemon is Syntharion
# Best Evolution_Level pokemon is Synthagon
# *********************
# TYPE BUG
# Best HP pokemon is Yanmega
# Best Attack pokemon is Mega Heracross
# Best Defense pokemon is Shuckle
# Best Sp. Atk pokemon is Volcarona
# Best Sp. Def pokemon is Shuckle
# Best Speed pokemon is Ninjask
# Best Evolution_Level pokemon is Mega Scizor
# *********************
# TYPE DARK
# Best HP pokemon is Yveltal
# Best Attack pokemon is Mega Absol
# Best Defense pokemon is Mega Sableye
# Best Sp. Atk pokemon is Mega Houndoom
# Best Sp. Def pokemon is Umbreon
# Best Speed pokemon is Darkrai
# Best Evolution_Level pokemon is Mega Sableye
# *********************
# TYPE DRAGON
# Best HP pokemon is Kyurem
# Best Attack pokemon is Mega Rayquaza
# Best Defense pokemon is Mega Salamence
# ...

# %% [markdown]
# ## 36. Gráfica de Pokemones agrupados por Generación
#
# Se grafico con plot el numero de Pokemones para cada generación

# %%
sns.countplot(x='Generation',hue=pokemons['Generation'],data=pokemons,palette='seismic')
plt.title('Number of pokemons grouped by generation')
plt.ylabel('Number of pokemons')
# Out:
# Text(0, 0.5, 'Number of pokemons')

# %% [markdown]
# ## 37. Suma de las estadísticas de todos los Pokemones por Generation
#
# Se muestra una tabla con la suma de todas las estadísticas de los Pokemones pertenecientes a la Generación correspondiente

# %%
pokemons[['Generation', '#','Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Legendary']].groupby('Generation').sum()
# Out:
#                   #    Total       HP   Attack  Defense  Sp. Atk  Sp. Def  \
# Generation
# 1.0         13171.0  70851.0  10926.0  12722.0  11763.0  11922.0  11469.0
# 2.0         21932.0  44333.0   7538.0   7627.0   7779.0   6982.0   7822.0
# 3.0         51515.0  69796.0  10647.0  13060.0  11856.0  12129.0  11396.0
# 4.0         53786.0  55551.0   8838.0  10037.0   9479.0   9218.0   9350.0
# 5.0         94831.0  71708.0  11862.0  13539.0  11909.0  11878.0  11342.0
# 6.0         56417.0  35783.0   5598.0   6216.0   6288.0   6092.0   6141.0
# 7.0           726.0    590.0     95.0    105.0     88.0    118.0    102.0
#
#               Speed Legendary
# Generation
# 1.0         12049.0         6
# 2.0          6537.0         5
# 3.0         10708.0        18
# 4.0          8607.0        13
# 5.0         11221.0        15
# 6.0          5448.0         8
# 7.0            96.0      True

# %% [markdown]
# ## 38. Graficando la suma de las estadísticas por Generación
#
# El código genera una figura con varios subgráficos donde se visualizan distintas estadísticas de los Pokémon por generación usando seaborn swarmplot, permitiendo comparar cómo varían los atributos entre generaciones.

# %%
plt.figure(figsize=(15,15))
k=1
for i in stats:
    plt.subplot(4,2,k)
    plt.subplots_adjust(hspace=0.4) 
    x=sns.swarmplot(x='Generation',hue=pokemons[i],y=i,data=pokemons,palette='plasma')
    k=k+1
    plt.title(i+str(' para cada generación'))
plt.show()

# %% [markdown]
# ## 39. Plotting (Graficado) con Boxplots
#
# Se usaron los mismos datos solo que esta vez usamos Boxplots

# %%
k=1
plt.figure(figsize=(17,15))
for i in stats:
    plt.subplot(4,2,k)
    plt.subplots_adjust(hspace=0.4) 
    sns.boxplot(y=pokemons[i],x=pokemons.Generation)
    k=k+1
    plt.title(i+str(' para cada generación'))

# %% [markdown]
# ## 40. Plotting (Graficado) con Bokeh
#
# Se graficaron los mismos datos pero con la gráfica de Bokeh

# %%
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.layouts import row, gridplot
output_notebook()

p1 = figure(width=400, height=200, title='HP for each generation')
p1.scatter(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,size=3,color='red')
p1.line(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,line_width=1,color='red')

# Attack
p2 = figure(width=400, height=200, title='HP for each generation')
p2.scatter(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,size=3,color='red')
p2.line(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,line_width=1,color='red')

# Defense
p3 = figure(width=400, height=200, title='HP for each generation')
p3.scatter(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,size=3,color='red')
p3.line(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,line_width=1,color='red')

# Sp. Atk
p4 = figure(width=400, height=200, title='HP for each generation')
p4.scatter(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,size=3,color='red')
p4.line(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,line_width=1,color='red')

# Sp. Def
p5 = figure(width=400, height=200, title='HP for each generation')
p5.scatter(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,size=3,color='red')
p5.line(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,line_width=1,color='red')

# Speed
p6 = figure(width=400, height=200, title='HP for each generation')
p6.scatter(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,size=3,color='red')
p6.line(x=[1,2,3,4,5,6,7],y=pokemons.groupby('Generation').sum().HP,line_width=1,color='red')

grid = gridplot([p1,p2,p3,p4,p5,p6],ncols=2)
show(grid)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f926b13e-748a-4336-bc35-65bbf43267d6">Loading BokehJS ...</span>
#     </div>
#   <div id="c31f895e-9573-4ac9-93ae-3b6d42b66976" data-root-id="p1333" style="display: contents;"></div>

# %% [markdown]
# ## 41. ¿Cuántos Pokemones Legendarios hay en el Dataset?

# %%
len(pokemons[pokemons.Legendary==True])
# Out:
# 66

# %% [markdown]
# ## 42. Conteo de Pokemones legendarios por generación

# %%
pokemons.groupby('Generation').sum().Legendary
# Out:
# Generation
# 1.0       6
# 2.0       5
# 3.0      18
# 4.0      13
# 5.0      15
# 6.0       8
# 7.0    True
# Name: Legendary, dtype: object

# %% [markdown]
# ## 43. Graficado de conteo de Pokemones legendarios por generación

# %%
sns.barplot(x=pokemons.groupby('Generation').sum().Legendary.index,
            hue=pokemons.groupby('Generation').sum().Legendary.index,
            y=pokemons.groupby('Generation').sum().Legendary.values,
            palette='CMRmap')
# Out:
# <Axes: xlabel='Generation'>

# %% [markdown]
# ## 44. ¿Cuántos Pokemones legendarios hay por cada tipo?

# %%
pokemons.groupby('Type').sum().Legendary.sort_values(ascending=False)
# Out:
# Type
# Psychic       14
# Dragon        12
# Fire           5
# Water          4
# Ground         4
# Steel          4
# Electric       4
# Rock           4
# Grass          3
# Normal         2
# Ice            2
# Ghost          2
# Flying         2
# Dark           2
# Fairy          1
# Artificial     1
# Bug            0
# Poison         0
# Fighting       0
# Name: Legendary, dtype: object

# %% [markdown]
# ## 45. Graficado de Pokemones legendarios por tipo

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=pokemons.groupby('Type').sum().Legendary.sort_values(ascending=False).index,
            hue=pokemons.groupby('Type').sum().Legendary.sort_values(ascending=False).index,
            y=pokemons.groupby('Type').sum().Legendary.sort_values(ascending=False).values,
           palette='Paired')
# Out:
# <Axes: xlabel='Type'>

# %% [markdown]
# ## 46. Comparación de estadísticas de Pokemones Legendarios
#
# Se comparan las estadísticas legendarias de los pokemones comparado con otros

# %%
k=1;
m=0;
plt.figure(figsize=(15,30))
for i in stats:
    plt.subplot(7,1,k);
    k=k+1;
    sns.swarmplot(x='Type',y=i,palette='Dark2',hue='Legendary',data=pokemons);
    plt.title(str('Total de ')+i+str(' para cada tipo'))
plt.show()

# %% [markdown]
# ## 47. Graficado de estadísticas de cada Tipo de Pokemon

# %%
plt.figure(figsize=(17,22))
k=1
for i in list_types:
    plt.subplot(7,3,k)
    k=k+1
    sns.swarmplot(x=pok_melt.variable,
                 y=pok_melt[pok_melt.Type==i].value,
                 palette='Dark2',
                 hue=pok_melt[pok_melt.Type==i].Legendary)
    plt.title(i)
    plt.xlabel('')
    plt.legend(bbox_to_anchor=(0,1.02,1,0.102),loc='lower left', ncol=2, mode="expand", borderaxespad=0)

# %% [markdown]
# ## 48. Pokemones legendarios con estadísticas arriba del promedio
#
# Se muestran los pokemones legendarios con estadísticas mayores al pokemon no legendario promedio

# %%
legend=pokemons[pokemons.Legendary==True]
for i in stats:
    print('Number of legendary pokemon with ',i,' higher than the average: ',
          len(legend[legend[i]>pokemons[i].mean()]),'\nPercentage:',round(len(legend[legend[i]>pokemons[i].mean()])/65*100,2),
         '\n*************')
# Out:
# Number of legendary pokemon with  HP  higher than the average:  60
# Percentage: 92.31
# *************
# Number of legendary pokemon with  Attack  higher than the average:  61
# Percentage: 93.85
# *************
# Number of legendary pokemon with  Defense  higher than the average:  56
# Percentage: 86.15
# *************
# Number of legendary pokemon with  Sp. Atk  higher than the average:  63
# Percentage: 96.92
# *************
# Number of legendary pokemon with  Sp. Def  higher than the average:  63
# Percentage: 96.92
# *************
# Number of legendary pokemon with  Speed  higher than the average:  62
# Percentage: 95.38
# *************
# Number of legendary pokemon with  Evolution_Level  higher than the average:  6
# Percentage: 9.23
# *************

# %% [markdown]
# ## 49. Graficado de estadísticas de Pokemones
#
# Se grafica con Heat Map para buscar correlacion en las variables (estadísticas)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(pokemons.drop(['#','Name','Type'],axis=1).corr(), annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ## 50. Graficado de estadísticas de Pokemones con Pairplot
#
# Se grafican las estadísticas de los Pokemones con la gráfica de Pairplot

# %%
sns.pairplot(pokemons.drop(['#','Legendary','Generation','Evolution_Level'],axis=1))
